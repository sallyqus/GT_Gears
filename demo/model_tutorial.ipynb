# %%
import sys
sys.path.append('../')

from gears import PertData, GEARS

# %% [markdown]
# Load data. We use norman as an example.

# %%
pert_data = PertData('./data')
pert_data.load(data_name = 'replogle_k562_essential')
pert_data.prepare_split(split = 'simulation', seed = 1)
pert_data.get_dataloader(batch_size = 32, test_batch_size = 128)
# Out:
# Found local copy...
# Found local copy...
# Found local copy...
# These perturbations are not in the GO graph and their perturbation can thus not be predicted
# ['C7orf26+ctrl' 'C14orf178+ctrl' 'RPS10-NUDT3+ctrl' 'SEM1+ctrl' 'FAU+ctrl']
# Creating pyg object for each cell in the data...
# Creating dataset file...
# 100%|██████████| 1088/1088 [15:01<00:00,  1.21it/s]
# Done!
# Saving new dataset pyg object at ./data\replogle_k562_essential\data_pyg\cell_graphs.pkl
# Done!
# Creating new splits....
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 3
#       1 pert_data = PertData('./data')
#       2 pert_data.load(data_name = 'replogle_k562_essential')
# ----> 3 pert_data.prepare_split(split = 'simulation', seed = 1)
#       4 pert_data.get_dataloader(batch_size = 32, test_batch_size = 128)
#
# File c:\Users\sisi\Documents\ox_project\GT_perturb\GT_Gears\demo\..\gears\pertdata.py:362, in PertData.prepare_split(self, split, seed, train_gene_set_size, combo_seen2_train_frac, combo_single_split_test_set_fraction, test_perts, only_test_set_perts, test_pert_genes, split_dict_path)
#     355     adata, subgroup = DS.split_data(train_gene_set_size = train_gene_set_size,
#     356                                     combo_seen2_train_frac = combo_seen2_train_frac,
#     357                                     seed=seed,
#     358                                     test_perts = test_perts,
#     359                                     only_test_set_perts = only_test_set_perts
#     360                                    )
#     361     subgroup_path = split_path[:-4] + '_subgroup.pkl'
# --> 362     pickle.dump(subgroup, open(subgroup_path, "wb"))
#     363     self.subgroup = subgroup
#     365 elif split[:5] == 'combo':
#     366     # combo perturbation
#
# FileNotFoundError: [Errno 2] No such file or directory: './data\\replogle_k562_essential\\splits\\data\\replogle_k562_essential_simulation_1_0.75_subgroup.pkl'

# %%
import sys
sys.path.append('../')

from gears import PertData

pert_data = PertData('./data') # specific saved folder
pert_data.new_data_process(dataset_name = 'replogle_k562_essential', adata = adata) # specific dataset name and adata object
pert_data.load(data_path = './data/replogle_k562_essential') # load the processed data, the path is saved folder + dataset_name
pert_data.prepare_split(split = 'simulation', seed = 1) # get data split with seed
pert_data.get_dataloader(batch_size = 32, test_batch_size = 128) # prepare data loader

# %% [markdown]
# Create a model object; if you use [wandb](https://wandb.ai), you can easily track model training and evaluation by setting `weight_bias_track` to true, and specify the `proj_name` and `exp_name` that you like.

# %%
gears_model = GEARS(pert_data, device = 'cuda:0',
                        weight_bias_track = False, 
                        proj_name = 'gt_gears',
                        exp_name = '2layers')
gears_model.model_initialize(hidden_size = 64)
# Out:
# Downloading...
# 100%|██████████| 60.7M/60.7M [00:02<00:00, 22.1MiB/s]
# Extracting tar file...
# Done!

# %% [markdown]
# You can find available tunable parameters in model_initialize via

# %%
gears_model.tunable_parameters()
# Out:
# {'hidden_size': 'hidden dimension, default 64',
#  'num_go_gnn_layers': 'number of GNN layers for GO graph, default 1',
#  'num_gene_gnn_layers': 'number of GNN layers for co-expression gene graph, default 1',
#  'decoder_hidden_size': 'hidden dimension for gene-specific decoder, default 16',
#  'num_similar_genes_go_graph': 'number of maximum similar K genes in the GO graph, default 20',
#  'num_similar_genes_co_express_graph': 'number of maximum similar K genes in the co expression graph, default 20',
#  'coexpress_threshold': 'pearson correlation threshold when constructing coexpression graph, default 0.4',
#  'uncertainty': 'whether or not to turn on uncertainty mode, default False',
#  'uncertainty_reg': 'regularization term to balance uncertainty loss and prediction loss, default 1',
#  'direction_lambda': 'regularization term to balance direction loss and prediction loss, default 1'}

# %% [markdown]
# Train your model:
#
# Note: For the sake of demo, we set epoch size to 1. To get full model, set `epochs = 20`.

# %%
gears_model.train(epochs = 1, lr= 1e-3)
# Out:
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.4685
# Epoch 1 Step 51 Train Loss: 0.4933
# Epoch 1 Step 101 Train Loss: 0.4362
# Epoch 1 Step 151 Train Loss: 0.5509
# Epoch 1 Step 201 Train Loss: 0.5882
# Epoch 1 Step 251 Train Loss: 0.4554
# Epoch 1 Step 301 Train Loss: 0.5501
# Epoch 1 Step 351 Train Loss: 0.4817
# Epoch 1 Step 401 Train Loss: 0.4106
# Epoch 1 Step 451 Train Loss: 0.4902
# Epoch 1 Step 501 Train Loss: 0.4780
# Epoch 1 Step 551 Train Loss: 0.4867
# Epoch 1 Step 601 Train Loss: 0.4862
# Epoch 1 Step 651 Train Loss: 0.5045
# Epoch 1 Step 701 Train Loss: 0.4377
# Epoch 1 Step 751 Train Loss: 0.5319
# Epoch 1 Step 801 Train Loss: 0.4658
# Epoch 1 Step 851 Train Loss: 0.5583
# Epoch 1 Step 901 Train Loss: 0.5629
# Epoch 1 Step 951 Train Loss: 0.4279
# Epoch 1 Step 1001 Train Loss: 0.4211
# Epoch 1 Step 1051 Train Loss: 0.4633
# Epoch 1 Step 1101 Train Loss: 0.4258
# Epoch 1 Step 1151 Train Loss: 0.4908
# Epoch 1 Step 1201 Train Loss: 0.4872
# Epoch 1 Step 1251 Train Loss: 0.4374
# Epoch 1 Step 1301 Train Loss: 0.5063
# Epoch 1 Step 1351 Train Loss: 0.4689
# Epoch 1 Step 1401 Train Loss: 0.5572
# Epoch 1 Step 1451 Train Loss: 0.4708
# Epoch 1 Step 1501 Train Loss: 0.4226
# Epoch 1 Step 1551 Train Loss: 0.4535
# Epoch 1: Train Overall MSE: 0.0051 Validation Overall MSE: 0.0053.
# Train Top 20 DE MSE: 0.1401 Validation Top 20 DE MSE: 0.2872.
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.2252
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: 0.008498766
# test_combo_seen0_pearson: 0.976215945172505
# test_combo_seen0_mse_de: 0.23012267
# test_combo_seen0_pearson_de: 0.7378072813052715
# test_combo_seen1_mse: 0.009902021
# test_combo_seen1_pearson: 0.9735781248339436
# test_combo_seen1_mse_de: 0.23493703
# test_combo_seen1_pearson_de: 0.860547002707191
# test_combo_seen2_mse: 0.007943115
# test_combo_seen2_pearson: 0.9780402481082581
# test_combo_seen2_mse_de: 0.23979782
# test_combo_seen2_pearson_de: 0.9165799617546899
# test_unseen_single_mse: 0.004571722
# test_unseen_single_pearson: 0.9870582446925614
# test_unseen_single_mse_de: 0.20469244
# test_unseen_single_pearson_de: 0.8727254301526481
# test_combo_seen0_pearson_delta: 0.5430041394339153
# test_combo_seen0_frac_opposite_direction_top20_non_dropout: 0.11666666666666667
# test_combo_seen0_frac_sigma_below_1_non_dropout: 0.7944444444444444
# test_combo_seen0_mse_top20_de_non_dropout: 0.2920846
# test_combo_seen1_pearson_delta: 0.5109012513984235
# test_combo_seen1_frac_opposite_direction_top20_non_dropout: 0.16046511627906973
# test_combo_seen1_frac_sigma_below_1_non_dropout: 0.7488372093023254
# test_combo_seen1_mse_top20_de_non_dropout: 0.30053407
# test_combo_seen2_pearson_delta: 0.5328579353692606
# test_combo_seen2_frac_opposite_direction_top20_non_dropout: 0.1289473684210526
# test_combo_seen2_frac_sigma_below_1_non_dropout: 0.8184210526315789
# test_combo_seen2_mse_top20_de_non_dropout: 0.24544433
# test_unseen_single_pearson_delta: 0.4050833686512697
# test_unseen_single_frac_opposite_direction_top20_non_dropout: 0.2222222222222222
# test_unseen_single_frac_sigma_below_1_non_dropout: 0.8527777777777777
# test_unseen_single_mse_top20_de_non_dropout: 0.2231014
# Done!

# %%
gears_model.train(epochs = 20,lr= 1e-3)
# Out:
# Start Training...
# Epoch 1 Step 1 Train Loss: 0.4688
# Epoch 1 Step 51 Train Loss: 0.4344
# Epoch 1 Step 101 Train Loss: 0.5985
# Epoch 1 Step 151 Train Loss: 0.4704
# Epoch 1 Step 201 Train Loss: 0.5722
# Epoch 1 Step 251 Train Loss: 0.4761
# Epoch 1 Step 301 Train Loss: 0.4620
# Epoch 1 Step 351 Train Loss: 0.4263
# Epoch 1 Step 401 Train Loss: 0.5280
# Epoch 1 Step 451 Train Loss: 0.5839
# Epoch 1 Step 501 Train Loss: 0.4090
# Epoch 1 Step 551 Train Loss: 0.6075
# Epoch 1 Step 601 Train Loss: 0.5147
# Epoch 1 Step 651 Train Loss: 0.5047
# Epoch 1 Step 701 Train Loss: 0.4495
# Epoch 1 Step 751 Train Loss: 0.4830
# Epoch 1 Step 801 Train Loss: 0.5066
# Epoch 1 Step 851 Train Loss: 0.5045
# Epoch 1 Step 901 Train Loss: 0.4824
# Epoch 1 Step 951 Train Loss: 0.4339
# Epoch 1 Step 1001 Train Loss: 0.4853
# Epoch 1 Step 1051 Train Loss: 0.4541
# Epoch 1 Step 1101 Train Loss: 0.4809
# Epoch 1 Step 1151 Train Loss: 0.4694
# Epoch 1 Step 1201 Train Loss: 0.5265
# Epoch 1 Step 1251 Train Loss: 0.5158
# Epoch 1 Step 1301 Train Loss: 0.5744
# Epoch 1 Step 1351 Train Loss: 0.4912
# Epoch 1 Step 1401 Train Loss: 0.5639
# Epoch 1 Step 1451 Train Loss: 0.5018
# Epoch 1 Step 1501 Train Loss: 0.4524
# Epoch 1 Step 1551 Train Loss: 0.6894
# Epoch 1: Train Overall MSE: 0.0026 Validation Overall MSE: 0.0032.
# Train Top 20 DE MSE: 0.1398 Validation Top 20 DE MSE: 0.2601.
# Epoch 2 Step 1 Train Loss: 0.4832
# Epoch 2 Step 51 Train Loss: 0.5130
# Epoch 2 Step 101 Train Loss: 0.4998
# Epoch 2 Step 151 Train Loss: 0.4915
# Epoch 2 Step 201 Train Loss: 0.5420
# Epoch 2 Step 251 Train Loss: 0.4625
# Epoch 2 Step 301 Train Loss: 0.4556
# Epoch 2 Step 351 Train Loss: 0.4718
# Epoch 2 Step 401 Train Loss: 0.4884
# Epoch 2 Step 451 Train Loss: 0.5581
# Epoch 2 Step 501 Train Loss: 0.5225
# Epoch 2 Step 551 Train Loss: 0.6242
# Epoch 2 Step 601 Train Loss: 0.4391
# Epoch 2 Step 651 Train Loss: 0.5147
# Epoch 2 Step 701 Train Loss: 0.4621
# Epoch 2 Step 751 Train Loss: 0.5269
# Epoch 2 Step 801 Train Loss: 0.4641
# Epoch 2 Step 851 Train Loss: 0.4750
# Epoch 2 Step 901 Train Loss: 0.4846
# Epoch 2 Step 951 Train Loss: 0.4467
# Epoch 2 Step 1001 Train Loss: 0.5355
# Epoch 2 Step 1051 Train Loss: 0.5538
# Epoch 2 Step 1101 Train Loss: 0.5140
# Epoch 2 Step 1151 Train Loss: 0.5306
# Epoch 2 Step 1201 Train Loss: 0.4575
# Epoch 2 Step 1251 Train Loss: 0.5487
# Epoch 2 Step 1301 Train Loss: 0.4346
# Epoch 2 Step 1351 Train Loss: 0.4650
# Epoch 2 Step 1401 Train Loss: 0.4938
# Epoch 2 Step 1451 Train Loss: 0.6150
# Epoch 2 Step 1501 Train Loss: 0.5044
# Epoch 2 Step 1551 Train Loss: 0.5090
# Epoch 2: Train Overall MSE: 0.0031 Validation Overall MSE: 0.0048.
# Train Top 20 DE MSE: 0.1148 Validation Top 20 DE MSE: 0.2586.
# Epoch 3 Step 1 Train Loss: 0.5336
# Epoch 3 Step 51 Train Loss: 0.5035
# Epoch 3 Step 101 Train Loss: 0.4572
# Epoch 3 Step 151 Train Loss: 0.4906
# Epoch 3 Step 201 Train Loss: 0.6163
# Epoch 3 Step 251 Train Loss: 0.5148
# Epoch 3 Step 301 Train Loss: 0.4663
# Epoch 3 Step 351 Train Loss: 0.5112
# Epoch 3 Step 401 Train Loss: 0.4643
# Epoch 3 Step 451 Train Loss: 0.5309
# Epoch 3 Step 501 Train Loss: 0.4574
# Epoch 3 Step 551 Train Loss: 0.4861
# Epoch 3 Step 601 Train Loss: 0.4341
# Epoch 3 Step 651 Train Loss: 0.5302
# Epoch 3 Step 701 Train Loss: 0.5498
# Epoch 3 Step 751 Train Loss: 0.5595
# Epoch 3 Step 801 Train Loss: 0.4657
# Epoch 3 Step 851 Train Loss: 0.5210
# Epoch 3 Step 901 Train Loss: 0.5021
# Epoch 3 Step 951 Train Loss: 0.5406
# Epoch 3 Step 1001 Train Loss: 0.4532
# Epoch 3 Step 1051 Train Loss: 0.5479
# Epoch 3 Step 1101 Train Loss: 0.4404
# Epoch 3 Step 1151 Train Loss: 0.5162
# Epoch 3 Step 1201 Train Loss: 0.4601
# Epoch 3 Step 1251 Train Loss: 0.5066
# Epoch 3 Step 1301 Train Loss: 0.5081
# Epoch 3 Step 1351 Train Loss: 0.5297
# Epoch 3 Step 1401 Train Loss: 0.5352
# Epoch 3 Step 1451 Train Loss: 0.5849
# Epoch 3 Step 1501 Train Loss: 0.4896
# Epoch 3 Step 1551 Train Loss: 0.5255
# Epoch 3: Train Overall MSE: 0.0027 Validation Overall MSE: 0.0041.
# Train Top 20 DE MSE: 0.0933 Validation Top 20 DE MSE: 0.2171.
# Epoch 4 Step 1 Train Loss: 0.4664
# Epoch 4 Step 51 Train Loss: 0.5338
# Epoch 4 Step 101 Train Loss: 0.4595
# Epoch 4 Step 151 Train Loss: 0.4496
# Epoch 4 Step 201 Train Loss: 0.5127
# Epoch 4 Step 251 Train Loss: 0.5159
# Epoch 4 Step 301 Train Loss: 0.4367
# Epoch 4 Step 351 Train Loss: 0.4982
# Epoch 4 Step 401 Train Loss: 0.4667
# Epoch 4 Step 451 Train Loss: 0.5615
# Epoch 4 Step 501 Train Loss: 0.5276
# Epoch 4 Step 551 Train Loss: 0.5070
# Epoch 4 Step 601 Train Loss: 0.4424
# Epoch 4 Step 651 Train Loss: 0.4165
# Epoch 4 Step 701 Train Loss: 0.5242
# Epoch 4 Step 751 Train Loss: 0.5605
# Epoch 4 Step 801 Train Loss: 0.5476
# Epoch 4 Step 851 Train Loss: 0.5036
# Epoch 4 Step 901 Train Loss: 0.5003
# Epoch 4 Step 951 Train Loss: 0.5237
# Epoch 4 Step 1001 Train Loss: 0.5308
# Epoch 4 Step 1051 Train Loss: 0.5055
# Epoch 4 Step 1101 Train Loss: 0.5876
# Epoch 4 Step 1151 Train Loss: 0.5299
# Epoch 4 Step 1201 Train Loss: 0.5969
# Epoch 4 Step 1251 Train Loss: 0.5248
# Epoch 4 Step 1301 Train Loss: 0.4863
# Epoch 4 Step 1351 Train Loss: 0.4847
# Epoch 4 Step 1401 Train Loss: 0.4842
# Epoch 4 Step 1451 Train Loss: 0.5314
# Epoch 4 Step 1501 Train Loss: 0.5366
# Epoch 4 Step 1551 Train Loss: 0.4596
# Epoch 4: Train Overall MSE: 0.0025 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0926 Validation Top 20 DE MSE: 0.2205.
# Epoch 5 Step 1 Train Loss: 0.4861
# Epoch 5 Step 51 Train Loss: 0.4968
# Epoch 5 Step 101 Train Loss: 0.4644
# Epoch 5 Step 151 Train Loss: 0.4586
# Epoch 5 Step 201 Train Loss: 0.4108
# Epoch 5 Step 251 Train Loss: 0.4728
# Epoch 5 Step 301 Train Loss: 0.5004
# Epoch 5 Step 351 Train Loss: 0.5553
# Epoch 5 Step 401 Train Loss: 0.5357
# Epoch 5 Step 451 Train Loss: 0.4580
# Epoch 5 Step 501 Train Loss: 0.5164
# Epoch 5 Step 551 Train Loss: 0.5091
# Epoch 5 Step 601 Train Loss: 0.4625
# Epoch 5 Step 651 Train Loss: 0.5671
# Epoch 5 Step 701 Train Loss: 0.4780
# Epoch 5 Step 751 Train Loss: 0.5115
# Epoch 5 Step 801 Train Loss: 0.5492
# Epoch 5 Step 851 Train Loss: 0.4870
# Epoch 5 Step 901 Train Loss: 0.5185
# Epoch 5 Step 951 Train Loss: 0.4499
# Epoch 5 Step 1001 Train Loss: 0.4629
# Epoch 5 Step 1051 Train Loss: 0.5251
# Epoch 5 Step 1101 Train Loss: 0.5258
# Epoch 5 Step 1151 Train Loss: 0.4557
# Epoch 5 Step 1201 Train Loss: 0.5241
# Epoch 5 Step 1251 Train Loss: 0.5307
# Epoch 5 Step 1301 Train Loss: 0.6627
# Epoch 5 Step 1351 Train Loss: 0.4736
# Epoch 5 Step 1401 Train Loss: 0.5692
# Epoch 5 Step 1451 Train Loss: 0.4821
# Epoch 5 Step 1501 Train Loss: 0.5186
# Epoch 5 Step 1551 Train Loss: 0.5045
# Epoch 5: Train Overall MSE: 0.0024 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0960 Validation Top 20 DE MSE: 0.2367.
# Epoch 6 Step 1 Train Loss: 0.6328
# Epoch 6 Step 51 Train Loss: 0.5901
# Epoch 6 Step 101 Train Loss: 0.5585
# Epoch 6 Step 151 Train Loss: 0.5087
# Epoch 6 Step 201 Train Loss: 0.4879
# Epoch 6 Step 251 Train Loss: 0.5012
# Epoch 6 Step 301 Train Loss: 0.6333
# Epoch 6 Step 351 Train Loss: 0.5417
# Epoch 6 Step 401 Train Loss: 0.5544
# Epoch 6 Step 451 Train Loss: 0.5077
# Epoch 6 Step 501 Train Loss: 0.5955
# Epoch 6 Step 551 Train Loss: 0.4842
# Epoch 6 Step 601 Train Loss: 0.5168
# Epoch 6 Step 651 Train Loss: 0.5219
# Epoch 6 Step 701 Train Loss: 0.4944
# Epoch 6 Step 751 Train Loss: 0.5237
# Epoch 6 Step 801 Train Loss: 0.4463
# Epoch 6 Step 851 Train Loss: 0.5171
# Epoch 6 Step 901 Train Loss: 0.5347
# Epoch 6 Step 951 Train Loss: 0.5099
# Epoch 6 Step 1001 Train Loss: 0.5209
# Epoch 6 Step 1051 Train Loss: 0.4498
# Epoch 6 Step 1101 Train Loss: 0.5238
# Epoch 6 Step 1151 Train Loss: 0.4807
# Epoch 6 Step 1201 Train Loss: 0.5559
# Epoch 6 Step 1251 Train Loss: 0.5070
# Epoch 6 Step 1301 Train Loss: 0.5179
# Epoch 6 Step 1351 Train Loss: 0.5299
# Epoch 6 Step 1401 Train Loss: 0.4797
# Epoch 6 Step 1451 Train Loss: 0.5048
# Epoch 6 Step 1501 Train Loss: 0.5820
# Epoch 6 Step 1551 Train Loss: 0.5382
# Epoch 6: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0994 Validation Top 20 DE MSE: 0.2385.
# Epoch 7 Step 1 Train Loss: 0.5258
# Epoch 7 Step 51 Train Loss: 0.4617
# Epoch 7 Step 101 Train Loss: 0.4937
# Epoch 7 Step 151 Train Loss: 0.5642
# Epoch 7 Step 201 Train Loss: 0.5144
# Epoch 7 Step 251 Train Loss: 0.4503
# Epoch 7 Step 301 Train Loss: 0.4849
# Epoch 7 Step 351 Train Loss: 0.6459
# Epoch 7 Step 401 Train Loss: 0.5286
# Epoch 7 Step 451 Train Loss: 0.5023
# Epoch 7 Step 501 Train Loss: 0.5725
# Epoch 7 Step 551 Train Loss: 0.5111
# Epoch 7 Step 601 Train Loss: 0.5359
# Epoch 7 Step 651 Train Loss: 0.4897
# Epoch 7 Step 701 Train Loss: 0.4432
# Epoch 7 Step 751 Train Loss: 0.5261
# Epoch 7 Step 801 Train Loss: 0.5366
# Epoch 7 Step 851 Train Loss: 0.4651
# Epoch 7 Step 901 Train Loss: 0.5009
# Epoch 7 Step 951 Train Loss: 0.5017
# Epoch 7 Step 1001 Train Loss: 0.5861
# Epoch 7 Step 1051 Train Loss: 0.5222
# Epoch 7 Step 1101 Train Loss: 0.5674
# Epoch 7 Step 1151 Train Loss: 0.4581
# Epoch 7 Step 1201 Train Loss: 0.6116
# Epoch 7 Step 1251 Train Loss: 0.5468
# Epoch 7 Step 1301 Train Loss: 0.5330
# Epoch 7 Step 1351 Train Loss: 0.5467
# Epoch 7 Step 1401 Train Loss: 0.4797
# Epoch 7 Step 1451 Train Loss: 0.5290
# Epoch 7 Step 1501 Train Loss: 0.5654
# Epoch 7 Step 1551 Train Loss: 0.5183
# Epoch 7: Train Overall MSE: 0.0024 Validation Overall MSE: 0.0038.
# Train Top 20 DE MSE: 0.0910 Validation Top 20 DE MSE: 0.2277.
# Epoch 8 Step 1 Train Loss: 0.4403
# Epoch 8 Step 51 Train Loss: 0.5673
# Epoch 8 Step 101 Train Loss: 0.5587
# Epoch 8 Step 151 Train Loss: 0.5566
# Epoch 8 Step 201 Train Loss: 0.5509
# Epoch 8 Step 251 Train Loss: 0.4545
# Epoch 8 Step 301 Train Loss: 0.5429
# Epoch 8 Step 351 Train Loss: 0.5599
# Epoch 8 Step 401 Train Loss: 0.4585
# Epoch 8 Step 451 Train Loss: 0.6305
# Epoch 8 Step 501 Train Loss: 0.4802
# Epoch 8 Step 551 Train Loss: 0.4840
# Epoch 8 Step 601 Train Loss: 0.5822
# Epoch 8 Step 651 Train Loss: 0.5557
# Epoch 8 Step 701 Train Loss: 0.4932
# Epoch 8 Step 751 Train Loss: 0.5303
# Epoch 8 Step 801 Train Loss: 0.7060
# Epoch 8 Step 851 Train Loss: 0.5103
# Epoch 8 Step 901 Train Loss: 0.5058
# Epoch 8 Step 951 Train Loss: 0.6450
# Epoch 8 Step 1001 Train Loss: 0.5729
# Epoch 8 Step 1051 Train Loss: 0.4824
# Epoch 8 Step 1101 Train Loss: 0.4730
# Epoch 8 Step 1151 Train Loss: 0.5290
# Epoch 8 Step 1201 Train Loss: 0.5097
# Epoch 8 Step 1251 Train Loss: 0.5435
# Epoch 8 Step 1301 Train Loss: 0.5456
# Epoch 8 Step 1351 Train Loss: 0.5361
# Epoch 8 Step 1401 Train Loss: 0.5774
# Epoch 8 Step 1451 Train Loss: 0.5419
# Epoch 8 Step 1501 Train Loss: 0.5622
# Epoch 8 Step 1551 Train Loss: 0.5100
# Epoch 8: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0036.
# Train Top 20 DE MSE: 0.1008 Validation Top 20 DE MSE: 0.2459.
# Epoch 9 Step 1 Train Loss: 0.5581
# Epoch 9 Step 51 Train Loss: 0.5690
# Epoch 9 Step 101 Train Loss: 0.5129
# Epoch 9 Step 151 Train Loss: 0.5098
# Epoch 9 Step 201 Train Loss: 0.5003
# Epoch 9 Step 251 Train Loss: 0.5328
# Epoch 9 Step 301 Train Loss: 0.4678
# Epoch 9 Step 351 Train Loss: 0.5267
# Epoch 9 Step 401 Train Loss: 0.5109
# Epoch 9 Step 451 Train Loss: 0.5227
# Epoch 9 Step 501 Train Loss: 0.4639
# Epoch 9 Step 551 Train Loss: 0.5348
# Epoch 9 Step 601 Train Loss: 0.6407
# Epoch 9 Step 651 Train Loss: 0.5364
# Epoch 9 Step 701 Train Loss: 0.4952
# Epoch 9 Step 751 Train Loss: 0.4851
# Epoch 9 Step 801 Train Loss: 0.5136
# Epoch 9 Step 851 Train Loss: 0.5645
# Epoch 9 Step 901 Train Loss: 0.5972
# Epoch 9 Step 951 Train Loss: 0.5447
# Epoch 9 Step 1001 Train Loss: 0.5659
# Epoch 9 Step 1051 Train Loss: 0.5241
# Epoch 9 Step 1101 Train Loss: 0.4956
# Epoch 9 Step 1151 Train Loss: 0.5849
# Epoch 9 Step 1201 Train Loss: 0.4561
# Epoch 9 Step 1251 Train Loss: 0.6003
# Epoch 9 Step 1301 Train Loss: 0.5478
# Epoch 9 Step 1351 Train Loss: 0.4960
# Epoch 9 Step 1401 Train Loss: 0.5033
# Epoch 9 Step 1451 Train Loss: 0.4914
# Epoch 9 Step 1501 Train Loss: 0.5289
# Epoch 9 Step 1551 Train Loss: 0.5834
# Epoch 9: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0036.
# Train Top 20 DE MSE: 0.0943 Validation Top 20 DE MSE: 0.2271.
# Epoch 10 Step 1 Train Loss: 0.4699
# Epoch 10 Step 51 Train Loss: 0.6733
# Epoch 10 Step 101 Train Loss: 0.5481
# Epoch 10 Step 151 Train Loss: 0.5683
# Epoch 10 Step 201 Train Loss: 0.5505
# Epoch 10 Step 251 Train Loss: 0.5273
# Epoch 10 Step 301 Train Loss: 0.5259
# Epoch 10 Step 351 Train Loss: 0.5485
# Epoch 10 Step 401 Train Loss: 0.6313
# Epoch 10 Step 451 Train Loss: 0.5738
# Epoch 10 Step 501 Train Loss: 0.4972
# Epoch 10 Step 551 Train Loss: 0.5012
# Epoch 10 Step 601 Train Loss: 0.5218
# Epoch 10 Step 651 Train Loss: 0.5762
# Epoch 10 Step 701 Train Loss: 0.6127
# Epoch 10 Step 751 Train Loss: 0.5971
# Epoch 10 Step 801 Train Loss: 0.4716
# Epoch 10 Step 851 Train Loss: 0.5360
# Epoch 10 Step 901 Train Loss: 0.4922
# Epoch 10 Step 951 Train Loss: 0.5510
# Epoch 10 Step 1001 Train Loss: 0.4438
# Epoch 10 Step 1051 Train Loss: 0.5243
# Epoch 10 Step 1101 Train Loss: 0.6007
# Epoch 10 Step 1151 Train Loss: 0.5599
# Epoch 10 Step 1201 Train Loss: 0.4989
# Epoch 10 Step 1251 Train Loss: 0.5277
# Epoch 10 Step 1301 Train Loss: 0.4894
# Epoch 10 Step 1351 Train Loss: 0.5225
# Epoch 10 Step 1401 Train Loss: 0.4805
# Epoch 10 Step 1451 Train Loss: 0.5907
# Epoch 10 Step 1501 Train Loss: 0.5420
# Epoch 10 Step 1551 Train Loss: 0.5540
# Epoch 10: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0939 Validation Top 20 DE MSE: 0.2298.
# Epoch 11 Step 1 Train Loss: 0.4947
# Epoch 11 Step 51 Train Loss: 0.5259
# Epoch 11 Step 101 Train Loss: 0.4753
# Epoch 11 Step 151 Train Loss: 0.4692
# Epoch 11 Step 201 Train Loss: 0.4698
# Epoch 11 Step 251 Train Loss: 0.5190
# Epoch 11 Step 301 Train Loss: 0.4545
# Epoch 11 Step 351 Train Loss: 0.4890
# Epoch 11 Step 401 Train Loss: 0.5069
# Epoch 11 Step 451 Train Loss: 0.5032
# Epoch 11 Step 501 Train Loss: 0.5042
# Epoch 11 Step 551 Train Loss: 0.5226
# Epoch 11 Step 601 Train Loss: 0.4732
# Epoch 11 Step 651 Train Loss: 0.5504
# Epoch 11 Step 701 Train Loss: 0.5168
# Epoch 11 Step 751 Train Loss: 0.4701
# Epoch 11 Step 801 Train Loss: 0.6203
# Epoch 11 Step 851 Train Loss: 0.5241
# Epoch 11 Step 901 Train Loss: 0.5332
# Epoch 11 Step 951 Train Loss: 0.4776
# Epoch 11 Step 1001 Train Loss: 0.4636
# Epoch 11 Step 1051 Train Loss: 0.5636
# Epoch 11 Step 1101 Train Loss: 0.4776
# Epoch 11 Step 1151 Train Loss: 0.4685
# Epoch 11 Step 1201 Train Loss: 0.5981
# Epoch 11 Step 1251 Train Loss: 0.5285
# Epoch 11 Step 1301 Train Loss: 0.5013
# Epoch 11 Step 1351 Train Loss: 0.5076
# Epoch 11 Step 1401 Train Loss: 0.4956
# Epoch 11 Step 1451 Train Loss: 0.4475
# Epoch 11 Step 1501 Train Loss: 0.5294
# Epoch 11 Step 1551 Train Loss: 0.5386
# Epoch 11: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0036.
# Train Top 20 DE MSE: 0.0975 Validation Top 20 DE MSE: 0.2387.
# Epoch 12 Step 1 Train Loss: 0.5038
# Epoch 12 Step 51 Train Loss: 0.4785
# Epoch 12 Step 101 Train Loss: 0.5454
# Epoch 12 Step 151 Train Loss: 0.4780
# Epoch 12 Step 201 Train Loss: 0.4785
# Epoch 12 Step 251 Train Loss: 0.5474
# Epoch 12 Step 301 Train Loss: 0.5144
# Epoch 12 Step 351 Train Loss: 0.5037
# Epoch 12 Step 401 Train Loss: 0.5125
# Epoch 12 Step 451 Train Loss: 0.5187
# Epoch 12 Step 501 Train Loss: 0.4641
# Epoch 12 Step 551 Train Loss: 0.5120
# Epoch 12 Step 601 Train Loss: 0.4823
# Epoch 12 Step 651 Train Loss: 0.5213
# Epoch 12 Step 701 Train Loss: 0.4887
# Epoch 12 Step 751 Train Loss: 0.5487
# Epoch 12 Step 801 Train Loss: 0.4621
# Epoch 12 Step 851 Train Loss: 0.5128
# Epoch 12 Step 901 Train Loss: 0.6427
# Epoch 12 Step 951 Train Loss: 0.5717
# Epoch 12 Step 1001 Train Loss: 0.4723
# Epoch 12 Step 1051 Train Loss: 0.6016
# Epoch 12 Step 1101 Train Loss: 0.5591
# Epoch 12 Step 1151 Train Loss: 0.4995
# Epoch 12 Step 1201 Train Loss: 0.5023
# Epoch 12 Step 1251 Train Loss: 0.4923
# Epoch 12 Step 1301 Train Loss: 0.5978
# Epoch 12 Step 1351 Train Loss: 0.4606
# Epoch 12 Step 1401 Train Loss: 0.6926
# Epoch 12 Step 1451 Train Loss: 0.5400
# Epoch 12 Step 1501 Train Loss: 0.5254
# Epoch 12 Step 1551 Train Loss: 0.4844
# Epoch 12: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0036.
# Train Top 20 DE MSE: 0.0966 Validation Top 20 DE MSE: 0.2312.
# Epoch 13 Step 1 Train Loss: 0.5101
# Epoch 13 Step 51 Train Loss: 0.5261
# Epoch 13 Step 101 Train Loss: 0.5069
# Epoch 13 Step 151 Train Loss: 0.5565
# Epoch 13 Step 201 Train Loss: 0.4979
# Epoch 13 Step 251 Train Loss: 0.5305
# Epoch 13 Step 301 Train Loss: 0.4984
# Epoch 13 Step 351 Train Loss: 0.5571
# Epoch 13 Step 401 Train Loss: 0.4834
# Epoch 13 Step 451 Train Loss: 0.5640
# Epoch 13 Step 501 Train Loss: 0.4899
# Epoch 13 Step 551 Train Loss: 0.5271
# Epoch 13 Step 601 Train Loss: 0.5154
# Epoch 13 Step 651 Train Loss: 0.5000
# Epoch 13 Step 701 Train Loss: 0.5280
# Epoch 13 Step 751 Train Loss: 0.4603
# Epoch 13 Step 801 Train Loss: 0.5288
# Epoch 13 Step 851 Train Loss: 0.5200
# Epoch 13 Step 901 Train Loss: 0.5728
# Epoch 13 Step 951 Train Loss: 0.5291
# Epoch 13 Step 1001 Train Loss: 0.4797
# Epoch 13 Step 1051 Train Loss: 0.5104
# Epoch 13 Step 1101 Train Loss: 0.5152
# Epoch 13 Step 1151 Train Loss: 0.4537
# Epoch 13 Step 1201 Train Loss: 0.5089
# Epoch 13 Step 1251 Train Loss: 0.5417
# Epoch 13 Step 1301 Train Loss: 0.5148
# Epoch 13 Step 1351 Train Loss: 0.5086
# Epoch 13 Step 1401 Train Loss: 0.5081
# Epoch 13 Step 1451 Train Loss: 0.5502
# Epoch 13 Step 1501 Train Loss: 0.5874
# Epoch 13 Step 1551 Train Loss: 0.6373
# Epoch 13: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0948 Validation Top 20 DE MSE: 0.2346.
# Epoch 14 Step 1 Train Loss: 0.4530
# Epoch 14 Step 51 Train Loss: 0.5454
# Epoch 14 Step 101 Train Loss: 0.5640
# Epoch 14 Step 151 Train Loss: 0.4811
# Epoch 14 Step 201 Train Loss: 0.5012
# Epoch 14 Step 251 Train Loss: 0.4829
# Epoch 14 Step 301 Train Loss: 0.4957
# Epoch 14 Step 351 Train Loss: 0.5599
# Epoch 14 Step 401 Train Loss: 0.5469
# Epoch 14 Step 451 Train Loss: 0.4893
# Epoch 14 Step 501 Train Loss: 0.4525
# Epoch 14 Step 551 Train Loss: 0.5268
# Epoch 14 Step 601 Train Loss: 0.4995
# Epoch 14 Step 651 Train Loss: 0.5566
# Epoch 14 Step 701 Train Loss: 0.4376
# Epoch 14 Step 751 Train Loss: 0.5038
# Epoch 14 Step 801 Train Loss: 0.4581
# Epoch 14 Step 851 Train Loss: 0.5253
# Epoch 14 Step 901 Train Loss: 0.5092
# Epoch 14 Step 951 Train Loss: 0.5014
# Epoch 14 Step 1001 Train Loss: 0.4753
# Epoch 14 Step 1051 Train Loss: 0.5607
# Epoch 14 Step 1101 Train Loss: 0.4627
# Epoch 14 Step 1151 Train Loss: 0.4722
# Epoch 14 Step 1201 Train Loss: 0.5426
# Epoch 14 Step 1251 Train Loss: 0.5484
# Epoch 14 Step 1301 Train Loss: 0.4926
# Epoch 14 Step 1351 Train Loss: 0.6114
# Epoch 14 Step 1401 Train Loss: 0.4946
# Epoch 14 Step 1451 Train Loss: 0.4444
# Epoch 14 Step 1501 Train Loss: 0.5314
# Epoch 14 Step 1551 Train Loss: 0.4895
# Epoch 14: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0933 Validation Top 20 DE MSE: 0.2336.
# Epoch 15 Step 1 Train Loss: 0.4416
# Epoch 15 Step 51 Train Loss: 0.4188
# Epoch 15 Step 101 Train Loss: 0.5499
# Epoch 15 Step 151 Train Loss: 0.4381
# Epoch 15 Step 201 Train Loss: 0.5216
# Epoch 15 Step 251 Train Loss: 0.6467
# Epoch 15 Step 301 Train Loss: 0.4449
# Epoch 15 Step 351 Train Loss: 0.4758
# Epoch 15 Step 401 Train Loss: 0.5722
# Epoch 15 Step 451 Train Loss: 0.4854
# Epoch 15 Step 501 Train Loss: 0.5145
# Epoch 15 Step 551 Train Loss: 0.5760
# Epoch 15 Step 601 Train Loss: 0.4924
# Epoch 15 Step 651 Train Loss: 0.4531
# Epoch 15 Step 701 Train Loss: 0.5653
# Epoch 15 Step 751 Train Loss: 0.5532
# Epoch 15 Step 801 Train Loss: 0.5081
# Epoch 15 Step 851 Train Loss: 0.5008
# Epoch 15 Step 901 Train Loss: 0.4652
# Epoch 15 Step 951 Train Loss: 0.4745
# Epoch 15 Step 1001 Train Loss: 0.5553
# Epoch 15 Step 1051 Train Loss: 0.5400
# Epoch 15 Step 1101 Train Loss: 0.5141
# Epoch 15 Step 1151 Train Loss: 0.5334
# Epoch 15 Step 1201 Train Loss: 0.5608
# Epoch 15 Step 1251 Train Loss: 0.5141
# Epoch 15 Step 1301 Train Loss: 0.4987
# Epoch 15 Step 1351 Train Loss: 0.5498
# Epoch 15 Step 1401 Train Loss: 0.5226
# Epoch 15 Step 1451 Train Loss: 0.5018
# Epoch 15 Step 1501 Train Loss: 0.5025
# Epoch 15 Step 1551 Train Loss: 0.5931
# Epoch 15: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0035.
# Train Top 20 DE MSE: 0.1037 Validation Top 20 DE MSE: 0.2289.
# Epoch 16 Step 1 Train Loss: 0.4842
# Epoch 16 Step 51 Train Loss: 0.5231
# Epoch 16 Step 101 Train Loss: 0.5391
# Epoch 16 Step 151 Train Loss: 0.4737
# Epoch 16 Step 201 Train Loss: 0.5304
# Epoch 16 Step 251 Train Loss: 0.5728
# Epoch 16 Step 301 Train Loss: 0.4309
# Epoch 16 Step 351 Train Loss: 0.4781
# Epoch 16 Step 401 Train Loss: 0.5548
# Epoch 16 Step 451 Train Loss: 0.5765
# Epoch 16 Step 501 Train Loss: 0.5011
# Epoch 16 Step 551 Train Loss: 0.4478
# Epoch 16 Step 601 Train Loss: 0.4767
# Epoch 16 Step 651 Train Loss: 0.6100
# Epoch 16 Step 701 Train Loss: 0.5549
# Epoch 16 Step 751 Train Loss: 0.5154
# Epoch 16 Step 801 Train Loss: 0.5055
# Epoch 16 Step 851 Train Loss: 0.4813
# Epoch 16 Step 901 Train Loss: 0.5055
# Epoch 16 Step 951 Train Loss: 0.4900
# Epoch 16 Step 1001 Train Loss: 0.5267
# Epoch 16 Step 1051 Train Loss: 0.5837
# Epoch 16 Step 1101 Train Loss: 0.5227
# Epoch 16 Step 1151 Train Loss: 0.4559
# Epoch 16 Step 1201 Train Loss: 0.5082
# Epoch 16 Step 1251 Train Loss: 0.5231
# Epoch 16 Step 1301 Train Loss: 0.5744
# Epoch 16 Step 1351 Train Loss: 0.5993
# Epoch 16 Step 1401 Train Loss: 0.6024
# Epoch 16 Step 1451 Train Loss: 0.5625
# Epoch 16 Step 1501 Train Loss: 0.4555
# Epoch 16 Step 1551 Train Loss: 0.4889
# Epoch 16: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0937 Validation Top 20 DE MSE: 0.2298.
# Epoch 17 Step 1 Train Loss: 0.5208
# Epoch 17 Step 51 Train Loss: 0.5544
# Epoch 17 Step 101 Train Loss: 0.5025
# Epoch 17 Step 151 Train Loss: 0.5115
# Epoch 17 Step 201 Train Loss: 0.5616
# Epoch 17 Step 251 Train Loss: 0.5641
# Epoch 17 Step 301 Train Loss: 0.4709
# Epoch 17 Step 351 Train Loss: 0.4463
# Epoch 17 Step 401 Train Loss: 0.4912
# Epoch 17 Step 451 Train Loss: 0.5033
# Epoch 17 Step 501 Train Loss: 0.5168
# Epoch 17 Step 551 Train Loss: 0.4767
# Epoch 17 Step 601 Train Loss: 0.5351
# Epoch 17 Step 651 Train Loss: 0.4903
# Epoch 17 Step 701 Train Loss: 0.5517
# Epoch 17 Step 751 Train Loss: 0.4980
# Epoch 17 Step 801 Train Loss: 0.5150
# Epoch 17 Step 851 Train Loss: 0.4651
# Epoch 17 Step 901 Train Loss: 0.5661
# Epoch 17 Step 951 Train Loss: 0.5393
# Epoch 17 Step 1001 Train Loss: 0.4637
# Epoch 17 Step 1051 Train Loss: 0.6753
# Epoch 17 Step 1101 Train Loss: 0.5808
# Epoch 17 Step 1151 Train Loss: 0.5711
# Epoch 17 Step 1201 Train Loss: 0.5075
# Epoch 17 Step 1251 Train Loss: 0.5252
# Epoch 17 Step 1301 Train Loss: 0.5042
# Epoch 17 Step 1351 Train Loss: 0.5102
# Epoch 17 Step 1401 Train Loss: 0.5595
# Epoch 17 Step 1451 Train Loss: 0.5196
# Epoch 17 Step 1501 Train Loss: 0.5175
# Epoch 17 Step 1551 Train Loss: 0.4710
# Epoch 17: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0916 Validation Top 20 DE MSE: 0.2240.
# Epoch 18 Step 1 Train Loss: 0.5296
# Epoch 18 Step 51 Train Loss: 0.4827
# Epoch 18 Step 101 Train Loss: 0.5535
# Epoch 18 Step 151 Train Loss: 0.4819
# Epoch 18 Step 201 Train Loss: 0.4959
# Epoch 18 Step 251 Train Loss: 0.5051
# Epoch 18 Step 301 Train Loss: 0.4771
# Epoch 18 Step 351 Train Loss: 0.4645
# Epoch 18 Step 401 Train Loss: 0.5350
# Epoch 18 Step 451 Train Loss: 0.5922
# Epoch 18 Step 501 Train Loss: 0.5468
# Epoch 18 Step 551 Train Loss: 0.5184
# Epoch 18 Step 601 Train Loss: 0.5110
# Epoch 18 Step 651 Train Loss: 0.5280
# Epoch 18 Step 701 Train Loss: 0.5153
# Epoch 18 Step 751 Train Loss: 0.5188
# Epoch 18 Step 801 Train Loss: 0.4685
# Epoch 18 Step 851 Train Loss: 0.4763
# Epoch 18 Step 901 Train Loss: 0.5051
# Epoch 18 Step 951 Train Loss: 0.4393
# Epoch 18 Step 1001 Train Loss: 0.5801
# Epoch 18 Step 1051 Train Loss: 0.4888
# Epoch 18 Step 1101 Train Loss: 0.5518
# Epoch 18 Step 1151 Train Loss: 0.5420
# Epoch 18 Step 1201 Train Loss: 0.5498
# Epoch 18 Step 1251 Train Loss: 0.5203
# Epoch 18 Step 1301 Train Loss: 0.5398
# Epoch 18 Step 1351 Train Loss: 0.5400
# Epoch 18 Step 1401 Train Loss: 0.5035
# Epoch 18 Step 1451 Train Loss: 0.5258
# Epoch 18 Step 1501 Train Loss: 0.5312
# Epoch 18 Step 1551 Train Loss: 0.5489
# Epoch 18: Train Overall MSE: 0.0023 Validation Overall MSE: 0.0037.
# Train Top 20 DE MSE: 0.0960 Validation Top 20 DE MSE: 0.2237.
# Epoch 19 Step 1 Train Loss: 0.4835
# Epoch 19 Step 51 Train Loss: 0.5807
# Epoch 19 Step 101 Train Loss: 0.5020
# Epoch 19 Step 151 Train Loss: 0.5028
# Epoch 19 Step 201 Train Loss: 0.5259
# Epoch 19 Step 251 Train Loss: 0.4908
# Epoch 19 Step 301 Train Loss: 0.5248
# Epoch 19 Step 351 Train Loss: 0.5213
# Epoch 19 Step 401 Train Loss: 0.5155
# Epoch 19 Step 451 Train Loss: 0.4988
# Epoch 19 Step 501 Train Loss: 0.5116
# Epoch 19 Step 551 Train Loss: 0.4981
# Epoch 19 Step 601 Train Loss: 0.5015
# Epoch 19 Step 651 Train Loss: 0.4581
# Epoch 19 Step 701 Train Loss: 0.5237
# Epoch 19 Step 751 Train Loss: 0.5428
# Epoch 19 Step 801 Train Loss: 0.5101
# Epoch 19 Step 851 Train Loss: 0.4873
# Epoch 19 Step 901 Train Loss: 0.4955
# Epoch 19 Step 951 Train Loss: 0.4869
# Epoch 19 Step 1001 Train Loss: 0.4723
# Epoch 19 Step 1051 Train Loss: 0.4849
# Epoch 19 Step 1101 Train Loss: 0.5027
# Epoch 19 Step 1151 Train Loss: 0.5296
# Epoch 19 Step 1201 Train Loss: 0.5217
# Epoch 19 Step 1251 Train Loss: 0.4848
# Epoch 19 Step 1301 Train Loss: 0.4378
# Epoch 19 Step 1351 Train Loss: 0.5675
# Epoch 19 Step 1401 Train Loss: 0.5668
# Epoch 19 Step 1451 Train Loss: 0.4735
# Epoch 19 Step 1501 Train Loss: 0.4914
# Epoch 19 Step 1551 Train Loss: 0.5641
# Epoch 19: Train Overall MSE: 0.0022 Validation Overall MSE: 0.0035.
# Train Top 20 DE MSE: 0.0993 Validation Top 20 DE MSE: 0.2362.
# Epoch 20 Step 1 Train Loss: 0.5287
# Epoch 20 Step 51 Train Loss: 0.5082
# Epoch 20 Step 101 Train Loss: 0.4810
# Epoch 20 Step 151 Train Loss: 0.4954
# Epoch 20 Step 201 Train Loss: 0.4299
# Epoch 20 Step 251 Train Loss: 0.5375
# Epoch 20 Step 301 Train Loss: 0.5359
# Epoch 20 Step 351 Train Loss: 0.5075
# Epoch 20 Step 401 Train Loss: 0.4639
# Epoch 20 Step 451 Train Loss: 0.4948
# Epoch 20 Step 501 Train Loss: 0.5003
# Epoch 20 Step 551 Train Loss: 0.4874
# Epoch 20 Step 601 Train Loss: 0.4531
# Epoch 20 Step 651 Train Loss: 0.5100
# Epoch 20 Step 701 Train Loss: 0.4633
# Epoch 20 Step 751 Train Loss: 0.5184
# Epoch 20 Step 801 Train Loss: 0.5331
# Epoch 20 Step 851 Train Loss: 0.4708
# Epoch 20 Step 901 Train Loss: 0.4659
# Epoch 20 Step 951 Train Loss: 0.5440
# Epoch 20 Step 1001 Train Loss: 0.4941
# Epoch 20 Step 1051 Train Loss: 0.5897
# Epoch 20 Step 1101 Train Loss: 0.4914
# Epoch 20 Step 1151 Train Loss: 0.4683
# Epoch 20 Step 1201 Train Loss: 0.5495
# Epoch 20 Step 1251 Train Loss: 0.5216
# Epoch 20 Step 1301 Train Loss: 0.5693
# Epoch 20 Step 1351 Train Loss: 0.5891
# Epoch 20 Step 1401 Train Loss: 0.5013
# Epoch 20 Step 1451 Train Loss: 0.5282
# Epoch 20 Step 1501 Train Loss: 0.5622
# Epoch 20 Step 1551 Train Loss: 0.4285
# Epoch 20: Train Overall MSE: 0.0024 Validation Overall MSE: 0.0038.
# Train Top 20 DE MSE: 0.0918 Validation Top 20 DE MSE: 0.2334.
# Done!
# Start Testing...
# Best performing model: Test Top 20 DE MSE: 0.1920
# Start doing subgroup analysis for simulation split...
# test_combo_seen0_mse: 0.0052900454
# test_combo_seen0_pearson: 0.9845775603550605
# test_combo_seen0_mse_de: 0.16105837
# test_combo_seen0_pearson_de: 0.7485148210343104
# test_combo_seen1_mse: 0.0061061964
# test_combo_seen1_pearson: 0.9824599831152984
# test_combo_seen1_mse_de: 0.18954894
# test_combo_seen1_pearson_de: 0.8605534421713451
# test_combo_seen2_mse: 0.005161021
# test_combo_seen2_pearson: 0.9854270064392556
# test_combo_seen2_mse_de: 0.19771926
# test_combo_seen2_pearson_de: 0.9124396498849487
# test_unseen_single_mse: 0.0030069072
# test_unseen_single_pearson: 0.9911268266252566
# test_unseen_single_mse_de: 0.19966763
# test_unseen_single_pearson_de: 0.8732076650827865
# test_combo_seen0_pearson_delta: 0.6230473670661653
# test_combo_seen0_frac_opposite_direction_top20_non_dropout: 0.09999999999999999
# test_combo_seen0_frac_sigma_below_1_non_dropout: 0.8388888888888889
# test_combo_seen0_mse_top20_de_non_dropout: 0.23670053
# test_combo_seen1_pearson_delta: 0.5720840647334196
# test_combo_seen1_frac_opposite_direction_top20_non_dropout: 0.15581395348837213
# test_combo_seen1_frac_sigma_below_1_non_dropout: 0.7674418604651163
# test_combo_seen1_mse_top20_de_non_dropout: 0.2671981
# test_combo_seen2_pearson_delta: 0.5963917763052429
# test_combo_seen2_frac_opposite_direction_top20_non_dropout: 0.1236842105263158
# test_combo_seen2_frac_sigma_below_1_non_dropout: 0.8421052631578947
# test_combo_seen2_mse_top20_de_non_dropout: 0.2125721
# test_unseen_single_pearson_delta: 0.4831642658677717
# test_unseen_single_frac_opposite_direction_top20_non_dropout: 0.20833333333333331
# test_unseen_single_frac_sigma_below_1_non_dropout: 0.8680555555555556
# test_unseen_single_mse_top20_de_non_dropout: 0.21746413
# Done!

# %% [markdown]
# Save and load pretrained models:

# %%
gears_model.save_model('test_model')
gears_model.load_pretrained('test_model')

# %% [markdown]
# Make prediction for new perturbation:

# %%
gears_model.predict([['FEV'], ['FEV', 'AHR']])
# Out:
# {'FEV': array([-1.5115363e-06,  4.4304952e-02,  1.0309354e-01, ...,
#          3.3967001e+00,  7.8529231e-03,  1.0920237e-31], dtype=float32),
#  'FEV_SAMD11': array([-2.2916190e-06,  9.7577907e-02,  1.6493453e-01, ...,
#          3.2082996e+00,  7.6769367e-03,  1.7619579e-31], dtype=float32)}

# %% [markdown]
# Gene list can be found here:

# %%
gears_model.gene_list[:5]
# Out:
# ['RP11-34P13.8', 'RP11-54O7.3', 'SAMD11', 'PERM1', 'HES4']
